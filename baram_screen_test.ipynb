# %%
import threading
import time
import random
from pynput import keyboard, mouse
import tkinter as tk
from tkinter import messagebox
import yaml
import pyautogui
import numpy as np

# %%
import pyautogui
import tkinter as tk

# 마우스 좌표를 실시간으로 확인하는 함수
def update_coordinates():
    x, y = pyautogui.position()  # 현재 마우스 좌표 얻기
    label.config(text=f"현재 마우스 좌표: ({x}, {y})")
    label.after(100, update_coordinates)  # 100ms마다 좌표 업데이트

# Tkinter GUI 설정
root = tk.Tk()
root.title("마우스 좌표 확인")

# 현재 마우스 위치 얻기
mouse_x, mouse_y = pyautogui.position()

# Tkinter 창의 위치 설정
# "+x+y" 형식으로 좌표 지정
root.geometry(f"+{mouse_x}+{mouse_y}")

label = tk.Label(root, text="현재 마우스 좌표: (0, 0)", font=("Arial", 14))
label.pack(pady=20)

# 좌표 업데이트 함수 호출
update_coordinates()

root.mainloop()

# %%
2400 - 4800 1350

# %%
# 게임창 전체 1200 x 900
# left_top = (1000, -1139)
left_top = (1002, -1250)
right_bot = (left_top[0]+1200, left_top[1]+900)

left_top_shift = (round(left_top[0]*0.8), round((left_top[1]+1350)*0.8))
right_bot_shift = (round(right_bot[0]*0.8), round((right_bot[1]+1350)*0.8))

width = right_bot_shift[0] - left_top_shift[0] #20배수
height = right_bot_shift[1] - left_top_shift[1] #16.25배수

game_region = (left_top_shift[0], left_top_shift[1], width, height)

hpmp_left_top = (left_top[0]+1005, left_top[1]+754) 1994 -506
hpmp_right_bot = (hpmp_left_top[0]+170, hpmp_left_top[1]+50) 2107 -477
hpmp_left_top_shift = (round(hpmp_left_top[0]*0.8), round((hpmp_left_top[1]+1350)*0.8))
hpmp_right_bot_shift = (round(hpmp_right_bot[0]*0.8), round((hpmp_right_bot[1]+1350)*0.8))

hpmp_width = hpmp_right_bot_shift[0] - hpmp_left_top_shift[0]
hpmp_height = hpmp_right_bot_shift[1] - hpmp_left_top_shift[1]

hpmp_region = (hpmp_left_top_shift[0], hpmp_left_top_shift[1], hpmp_width, hpmp_height)

print(f"self.game_region = {game_region}")
print(f"self.hpmp_region = {hpmp_region}")
# Out:
# self.game_region = (802, 80, 960, 720)
# self.hpmp_region = (1595, 675, 91, 24)

# %%
## 옛날바람
# 게임창 전체 1200 x 900
left_top = (3480, 236) # 3485 230
right_bot = (left_top[0]+1038, left_top[1]+598) # 4523 828

left_top_shift = (round((1920 + (left_top[0]-2400)*0.8)), round((left_top[1]+0)*0.8))
right_bot_shift = (round(1920 + (right_bot[0]-2400)*0.8), round((right_bot[1]+0)*0.8))

width = right_bot_shift[0] - left_top_shift[0] #20배수
height = right_bot_shift[1] - left_top_shift[1] #16.25배수

game_region = (left_top_shift[0], left_top_shift[1], width, height)

hpmp_left_top = (left_top[0]+910, left_top[1]+504) # 4393 734
hpmp_right_bot = (hpmp_left_top[0]+113, hpmp_left_top[1]+30) #4505 759
hpmp_left_top_shift = (round(1920 + (hpmp_left_top[0]-2400)*0.8), round((hpmp_left_top[1]+0)*0.8))
hpmp_right_bot_shift = (round(1920 + (hpmp_right_bot[0]-2400)*0.8), round((hpmp_right_bot[1]+0)*0.8))

hpmp_width = hpmp_right_bot_shift[0] - hpmp_left_top_shift[0]
hpmp_height = hpmp_right_bot_shift[1] - hpmp_left_top_shift[1]

hpmp_region = (hpmp_left_top_shift[0], hpmp_left_top_shift[1], hpmp_width, hpmp_height)

print(f"self.game_region = {game_region}")
print(f"self.hpmp_region = {hpmp_region}")
# Out:
# self.game_region = (2784, 189, 830, 478)
# self.hpmp_region = (3512, 592, 90, 24)

# %%
1525-520
# Out:
# 1005

# %%
## 바람클래식 갤럭시북
# 게임창 전체 1200 x 900
left_top = (520, 115)
right_bot = (left_top[0]+1200, left_top[1]+900) #1715 1005

width = right_bot[0] - left_top[0] #20배수
height = right_bot[1] - left_top[1] #16.25배수

game_region = (left_top[0], left_top[1], width, height)

hpmp_left_top = (left_top[0]+1006, left_top[1]+750) #1525,865
hpmp_right_bot = (hpmp_left_top[0]+165, hpmp_left_top[1]+50) #1690,900

hpmp_width = hpmp_right_bot[0] - hpmp_left_top[0]
hpmp_height = hpmp_right_bot[1] - hpmp_left_top[1]

hpmp_region = (hpmp_left_top[0], hpmp_left_top[1], hpmp_width, hpmp_height)

print(f"self.game_region = {game_region}")
print(f"self.hpmp_region = {hpmp_region}")
# Out:
# self.game_region = (520, 115, 1200, 900)
# self.hpmp_region = (1526, 865, 165, 50)

# %%
pyautogui.screenshot(region=game_region, allScreens=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x900>

# %%
pyautogui.screenshot(region=hpmp_region, allScreens=True)
# Out:
# <PIL.Image.Image image mode=RGB size=165x50>

# %%
## 옛날바람 갤럭시북
# 게임창 전체 1200 x 900
left_top = (223, 51)
right_bot = (left_top[0]+1665, left_top[1]+956)

width = right_bot[0] - left_top[0] #20배수
height = right_bot[1] - left_top[1] #16.25배수

game_region = (left_top[0], left_top[1], width, height)

hpmp_left_top = (left_top[0]+1456, left_top[1]+808) #1647,860
hpmp_right_bot = (hpmp_left_top[0]+183, hpmp_left_top[1]+44) #1829,903

hpmp_width = hpmp_right_bot[0] - hpmp_left_top[0]
hpmp_height = hpmp_right_bot[1] - hpmp_left_top[1]

hpmp_region = (hpmp_left_top[0], hpmp_left_top[1], hpmp_width, hpmp_height)

print(f"self.game_region = {game_region}")
print(f"self.hpmp_region = {hpmp_region}")
# Out:
# self.game_region = (223, 51, 1665, 956)
# self.hpmp_region = (1679, 859, 183, 44)

# %%
pyautogui.screenshot(region=game_region, allScreens=True)
# Out:
# <PIL.Image.Image image mode=RGB size=830x478>

# %%
pyautogui.screenshot(region=hpmp_region, allScreens=True)
# Out:
# <PIL.Image.Image image mode=RGB size=90x24>

# %%
def display_color(rgb_color):
    r, g, b = rgb_color
    print(f"\033[48;2;{r};{g};{b}m      \033[0m RGB: {rgb_color}")

# %%
screenshot = pyautogui.screenshot(region=hpmp_region, allScreens=True)
mp_color = screenshot.getpixel((round(0.5 * hpmp_region[2]),round(hpmp_region[3]*3/4)))
hp_color = screenshot.getpixel((round(0.4 * hpmp_region[2]),round(hpmp_region[3]/4)))
display_color(mp_color)
display_color(hp_color)
# Out:
#        RGB: (173, 190, 214)
#        RGB: (231, 65, 0)

# %%
mp_color_low = [screenshot.getpixel((round(1-x * hpmp_region[2]),round(hpmp_region[3]*3/4))) for x in np.arange(0.1, 0.2, 0.005)]

# %%
for i in mp_color_low:
    display_color(i)
# Out:
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (8, 4, 8)
#        RGB: (8, 4, 8)
#        RGB: (8, 4, 8)
#        RGB: (8, 4, 8)
#        RGB: (8, 4, 8)
#        RGB: (8, 4, 8)
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (91, 131, 59)
#        RGB: (91, 131, 59)
#        RGB: (91, 131, 59)
#        RGB: (91, 131, 59)
#        RGB: (91, 131, 59)
#        RGB: (91, 131, 59)
#        RGB: (0, 0, 0)

# %%
np.mean(mp_color_low)
# Out:
# 30.1

# %%
mp_thres = 0.5
hp_thres = 0.5

# %%
screenshot = pyautogui.screenshot(region=hpmp_region, allScreens=True)
hp_color = [screenshot.getpixel((round((1-x) * hpmp_region[2]),round(hpmp_region[3]/4))) for x in np.arange(hp_thres-0.1, hp_thres, 0.005)]
for i in hp_color:
    display_color(i)
hp_color= np.mean(hp_color)
hp_color
# Out:
#        RGB: (0, 0, 0)
#        RGB: (0, 0, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (231, 65, 0)
#        RGB: (118, 34, 2)
#        RGB: (118, 34, 2)
#        RGB: (8, 4, 8)
# 79.46666666666667

# %%
round((1-0.4) * hpmp_region[2])
# Out:
# 54

# %%
screenshot
# Out:
# <PIL.Image.Image image mode=RGB size=90x24>

# %%
pyautogui.screenshot(region=(1594, 680, 54, 6), allScreens=True)
# Out:
# <PIL.Image.Image image mode=RGB size=54x6>

# %%
1-0.2 * hpmp_region[2]
# Out:
# -17.0

# %%
hpmp_region[2] * 0.8
# Out:
# 72.0

# %%
24/4
# Out:
# 6.0

# %%
hpmp_region
# Out:
# (1594, 680, 90, 24)

# %%
hpmp_region[3]
# Out:
# 24

# %%
screenshot
# Out:
# <PIL.Image.Image image mode=RGB size=90x24>

# %%
for _ in range(15):
    _active_skill(skill_name='heal', target_iter=2)
time.sleep(0.05)
keyboard_controller.press(keyboard.Key.esc)
keyboard_controller.release(keyboard.Key.esc)
screenshot = pyautogui.screenshot(region=hpmp_region, allScreens=True)
hp_color = np.mean([screenshot.getpixel((round(1-x * hpmp_region[2]),round(hpmp_region[3]/4))) for x in np.arange(hp_thres-0.1, hp_thres, 0.01)])

# %%
import threading
import time
import random
from pynput import keyboard, mouse
import tkinter as tk
from tkinter import messagebox
import pyautogui
import yaml
import pytesseract
import cv2
import numpy as np
from PIL import Image

pytesseract.pytesseract.tesseract_cmd = './Tesseract-OCR/tesseract.exe'


def capture_and_crop(screenshot, crop_area=None):
    """
    화면 캡처 후 특정 영역을 자름
    :param crop_area: 잘라낼 영역 (x, y, width, height)
    :return: 잘라낸 이미지 (NumPy 배열)
    """
    # 화면 캡처
    screenshot_np = np.array(screenshot)
    image = cv2.cvtColor(screenshot_np, cv2.COLOR_RGB2BGR)  # OpenCV BGR 포맷으로 변환
    x, y, w, h = crop_area
    cropped_image = image[y:y+h, x:x+w]
    cropped_image = Image.fromarray(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
    return cropped_image

def merge_close_coordinates(coordinates, threshold=20):
    """
    가까운 좌표들을 병합하는 함수.
    
    :param coordinates: [(x1, y1), (x2, y2), ...] 형식의 좌표 리스트
    :param threshold: 병합할 최대 거리 임계값
    :return: 병합된 좌표 리스트
    """
    if not coordinates:
        return []

    # numpy 배열로 변환
    coords_array = np.array(coordinates)

    # 결과 저장용 리스트
    merged_coords = []

    # 방문 여부 확인 리스트
    visited = [False] * len(coordinates)

    for i, coord in enumerate(coords_array):
        if visited[i]:
            continue

        # 현재 좌표를 기준으로 병합
        close_group = [coord]
        visited[i] = True

        for j, other_coord in enumerate(coords_array):
            if not visited[j]:
                # 유클리드 거리 계산
                distance = np.linalg.norm(coord - other_coord)
                if distance <= threshold:
                    close_group.append(other_coord)
                    visited[j] = True

        # 그룹의 최소 계산
        group_center = np.min(close_group, axis=0)
        merged_coords.append(tuple(group_center))

    return merged_coords



def image_detection(screenshot, image_path_list, confidence=0.8, show=False):
    screenshot_np = np.array(screenshot)  # PIL 이미지를 NumPy 배열로 변환 (BGR 형식)
    screenshot_np = cv2.cvtColor(screenshot_np, cv2.COLOR_RGB2BGR)  # RGB → BGR 변환
    
    coordinates = []
    for image_path in image_path_list:
        image = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)
        h, w = image.shape[:2]  # 높이와 너비 가져오기

        # 템플릿 매칭
        result = cv2.matchTemplate(screenshot_np, image, cv2.TM_CCOEFF_NORMED)
        locations = np.where(result >= confidence)  # 매칭된 위치 추출 (신뢰도 기준)
        coordinate = list(zip(locations[1], locations[0]))
        coordinate = merge_close_coordinates(coordinate, threshold=20)
        for coordinate_ in coordinate:
            # coordinates.append(coordinate_)
            coordinates.append((round(coordinate_[0] + w // 2), round(coordinate_[1] + h // 2)))
        
    if show:
        for pt in coordinates:
            cv2.rectangle(screenshot_np, pt, (pt[0] + 1, pt[1] + 1), (0, 255, 0), 5)
        cv2.imshow('Matches', screenshot_np)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        
    return coordinates

def extract_text_from_image(region, cut_region=(360,190,290,230), config=r'--oem 1 --psm 6'):
    screenshot = pyautogui.screenshot(region=region, allScreens=True)
    screenshot_cut = capture_and_crop(screenshot, cut_region)
    screenshot_np = np.array(screenshot_cut)
    screenshot_gray = cv2.cvtColor(screenshot_np, cv2.COLOR_BGR2GRAY)
    extracted_text = pytesseract.image_to_string(screenshot_gray, lang='kor', config=config)
    return extracted_text

# %%
game_region = (802, 80, 960, 720)
hpmp_region = (1606, 683, 136, 40)
kingq_region_cut = (280, 180, 290, 230)

delay = random.uniform(0.005, 0.001)
phase = 1

# %%
screenshot = pyautogui.screenshot(region=game_region, allScreens=True)
screenshot_cut = capture_and_crop(screenshot, kingq_region_cut)
screenshot_cut
# Out:
# <PIL.Image.Image image mode=RGB size=290x230>

# %%
extracted_text = extract_text_from_image(game_region, cut_region=kingq_region_cut, config=r'--oem 1 --psm 6')
extracted_text
# Out:
# '|소시켜주십시오.\n!수하고 다시 오겠습니다.\n'

# %%
'다시' in extracted_text
# Out:
# True

# %%
screenshot = pyautogui.screenshot(region=game_region, allScreens=True)
king_coord = image_detection(screenshot, ['king2.jpg'], 0.8, show=False)

# %%
# Out:
# '무례하게 폐하께 직접! 폐하께\n전할 말씀은 나를 통해서 하시오!\n'

# %%
delay = random.uniform(0.005, 0.001)
phase = 1

while True:
    screenshot = pyautogui.screenshot(region=self.game_region, allScreens=True)
    king_coord = image_detection(screenshot, ['king2.jpg'], 0.8, show=False)

    if len(king_coord) == 0:
        time.sleep(0.5)
    else:
        # 첫 번째 좌표로 마우스 이동
        target_x = round((self.game_region[0] + king_coord[0][0])/0.8)
        target_y = round((self.game_region[1] + king_coord[0][1])/0.8) - 1350

        pyautogui.moveTo(target_x, target_y, duration=0.1)  # 마우스 이동 (0.5초 동안 이동)
        pyautogui.click()
        pyautogui.moveTo(self.game_region[0]/0.8, self.game_region[1]/0.8-1350, duration=0.1)  # 마우스 이동 (0.5초 동안 이동)

        extracted_text = extract_text_from_image(self.game_region, cut_region=self.kingq_region_cut, config=r'--oem 1 --psm 6')
        if self.target_monster in self.kingq_wish:
            if '받든' in extracted_text:
                self.target_monster = 'Nobody'
                self.keyboard_controller.press(keyboard.Key.space)
                self.keyboard_controller.release(keyboard.Key.space)
                time.sleep(1)
                pyautogui.moveTo(target_x, target_y, duration=0.1)  # 마우스 이동 (0.5초 동안 이동)
                pyautogui.click()
                pyautogui.moveTo(self.game_region[0]/0.8, self.game_region[1]/0.8-1350, duration=0.1)  # 마우스 이동 (0.5초 동안 이동)
                extracted_text = extract_text_from_image(self.game_region, cut_region=self.kingq_region_cut, config=r'--oem 1 --psm 6')

        if phase == 1:
            for ti, text in enumerate(self.kings_speech[:4]):
                while text in extracted_text:
                    if ti == 2:
                        for _ in range(50):
                            self.keyboard_controller.press(keyboard.Key.left)
                            self.keyboard_controller.release(keyboard.Key.left)
                            time.sleep(delay)
                    if ti == 3:
                        self.target_monster = extracted_text.split('!')[1].split('을')[0].strip()
                        self.kings_speech[4] = self.target_monster
                        phase = 2
                    self.keyboard_controller.press(keyboard.Key.space)
                    self.keyboard_controller.release(keyboard.Key.space)
                    time.sleep(delay)
                    extracted_text = extract_text_from_image(self.game_region, cut_region=self.kingq_region_cut, config=r'--oem 1 --psm 6')

            self.keyboard_controller.release(keyboard.Key.esc)

            if self.target_monster in self.kingq_wish:
                break

        elif phase == 2:
            for ti, text in enumerate(self.kings_speech[4:]):
                while text in extracted_text:
                    if ti == 1:
                        for _ in range(50):
                            self.keyboard_controller.press(keyboard.Key.left)
                            self.keyboard_controller.release(keyboard.Key.left)
                            time.sleep(delay)
                    if ti == 3:
                        self.target_monster = 'Nobody'
                        phase = 1
                    self.keyboard_controller.press(keyboard.Key.space)
                    self.keyboard_controller.release(keyboard.Key.space)
                    time.sleep(delay)
                    extracted_text = extract_text_from_image(self.game_region, cut_region=self.kingq_region_cut, config=r'--oem 1 --psm 6')        
        time.sleep(delay)
        self.keyboard_controller.press(keyboard.Key.space)
        self.keyboard_controller.release(keyboard.Key.space)

self.state['kingq'] = False
self.kingq_button.config(state=tk.NORMAL)
self.start_auto_gongj_heal()
